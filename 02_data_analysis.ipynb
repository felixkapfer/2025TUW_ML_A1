# %% [markdown]
# # 1. Intorduction
#
# Before we can start preprocessing the data, we first need to analyize it, in order to understand the data. This notebook will be used, to perform basic analysis over the two data sets, including the loan dataset as well as the breast cancer dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # 2. Loan Dataset Analysis

# %%
ds_loan = pd.read_csv('./data/ds_loan/loan-10k.lrn.csv')

# %%
display(ds_loan.head())
# Out:
#       ID  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  24341    12500.0      12500.0          12500.0   36 months      7.21
# 1  67534    33850.0      33850.0          33775.0   60 months     20.99
# 2  35080    10000.0      10000.0          10000.0   60 months     20.00
# 3   4828    20250.0      20250.0          20250.0   36 months     14.31
# 4  59259    25000.0      25000.0          25000.0   36 months     14.99
#
#    installment emp_length home_ownership  annual_inc  ...  \
# 0       387.17   < 1 year       MORTGAGE     81000.0  ...
# 1       915.57     1 year       MORTGAGE     80000.0  ...
# 2       264.94   < 1 year           RENT     36580.0  ...
# 3       695.15    9 years           RENT     48700.0  ...
# 4       866.52     1 year       MORTGAGE     85000.0  ...
#
#   debt_settlement_flag issue_d_month issue_d_year earliest_cr_line_month  \
# 0                    N             6         2018                      6
# ...

# %%
ds_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 92 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          10000 non-null  int64
#  1   loan_amnt                   10000 non-null  float64
#  2   funded_amnt                 10000 non-null  float64
#  3   funded_amnt_inv             10000 non-null  float64
#  4   term                        10000 non-null  object
#  5   int_rate                    10000 non-null  float64
#  6   installment                 10000 non-null  float64
#  7   emp_length                  10000 non-null  object
#  8   home_ownership              10000 non-null  object
#  9   annual_inc                  10000 non-null  float64
#  10  verification_status         10000 non-null  object
#  11  loan_status                 10000 non-null  object
#  12  pymnt_plan                  10000 non-null  object
# ...

# %%
ds_loan.shape
# Out:
# (10000, 92)

# %%
ds_loan.describe()
# Out:
#                  ID     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  10000.000000  10000.000000  10000.000000     10000.000000
# mean   50043.430200  15631.152500  15631.152500     15625.992500
# std    28982.440166   9314.246117   9314.246117      9312.426843
# min        0.000000   1000.000000   1000.000000      1000.000000
# 25%    24873.250000   8350.000000   8350.000000      8343.750000
# 50%    50033.500000  14000.000000  14000.000000     14000.000000
# 75%    75261.500000  21000.000000  21000.000000     21000.000000
# max    99999.000000  40000.000000  40000.000000     40000.000000
#
#            int_rate   installment    annual_inc           dti   delinq_2yrs  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean      13.216959    461.084183  8.212897e+04     19.089188      0.303400
# std        4.855838    269.903751  6.769284e+04      9.523219      0.841201
# ...
